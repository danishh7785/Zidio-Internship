# %%
import pandas as pd
df=pd.read_csv("stock .csv",skiprows=2)

# %%
df.head()
# Out:
#          Date  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0  02-01-2020   72.620842   72.681289   71.373218   71.627092   135480400
# 1  03-01-2020   71.914825   72.676454   71.689965   71.847125   146322800
# 2  06-01-2020   72.487846   72.526533   70.783248   71.034709   118387200
# 3  07-01-2020   72.146935   72.753816   71.926907   72.497522   108872000
# 4  08-01-2020   73.307503   73.609737   71.849525   71.849525   132079200

# %%
df['Date']=pd.to_datetime(df['Date'],dayfirst=True)

# %%
df.set_index("Date",inplace=True)

# %%
print(df.head())
# Out:
#             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# Date
# 2020-01-02   72.620842   72.681289   71.373218   71.627092   135480400
# 2020-01-03   71.914825   72.676454   71.689965   71.847125   146322800
# 2020-01-06   72.487846   72.526533   70.783248   71.034709   118387200
# 2020-01-07   72.146935   72.753816   71.926907   72.497522   108872000
# 2020-01-08   73.307503   73.609737   71.849525   71.849525   132079200

# %%
df.columns=['Close','High','Low','Open','Volume']

# %%
print(df.head())
# Out:
#                 Close       High        Low       Open     Volume
# Date
# 2020-01-02  72.620842  72.681289  71.373218  71.627092  135480400
# 2020-01-03  71.914825  72.676454  71.689965  71.847125  146322800
# 2020-01-06  72.487846  72.526533  70.783248  71.034709  118387200
# 2020-01-07  72.146935  72.753816  71.926907  72.497522  108872000
# 2020-01-08  73.307503  73.609737  71.849525  71.849525  132079200

# %%
df.describe()
# Out:
#             Close        High         Low        Open        Volume
# count  505.000000  505.000000  505.000000  505.000000  5.050000e+02
# mean   115.319393  116.623322  113.880644  115.218469  1.241110e+08
# std     29.137462   29.284374   28.967715   29.150404  6.315499e+07
# min     54.378574   55.379527   51.528408   55.277736  4.100000e+07
# 25%     89.073128   90.373263   88.370797   88.730458  8.086110e+07
# 50%    120.898590  122.107506  119.255078  120.898740  1.088292e+08
# 75%    138.299820  139.377918  135.614405  137.075156  1.477512e+08
# max    176.996689  178.763430  175.229990  177.772090  4.265100e+08

# %%
print(df.dtypes)
# Out:
# Close     float64
# High      float64
# Low       float64
# Open      float64
# Volume      int64
# dtype: object

# %%
#categorical dat to check if present convert into numerical form
non_numeric=df.select_dtypes(exclude=['number','datetime'])

# %%
print(non_numeric.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-01-02 00:00:00, 2020-01-03 00:00:00, 2020-01-06 00:00:00, 2020-01-07 00:00:00, 2020-01-08 00:00:00]

# %%
for col in non_numeric:
  print(f"\nUnique values in {col}:")
  print(df[col].unique())
