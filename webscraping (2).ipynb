# %%
import yfinance as yf
import pandas as pd

# %%
df=yf.download("AAPL",start="2020-01-01",end="2022-01-01")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.620842  72.681289  71.373218  71.627092  135480400
# 2020-01-03  71.914825  72.676454  71.689965  71.847125  146322800
# 2020-01-06  72.487846  72.526533  70.783248  71.034709  118387200
# 2020-01-07  72.146935  72.753816  71.926907  72.497522  108872000
# 2020-01-08  73.307503  73.609737  71.849525  71.849525  132079200

# %%
df.to_csv("aapl_stock.csv",index=True)

# %%
from google.colab import files
files.download("aapl_stock.csv")
